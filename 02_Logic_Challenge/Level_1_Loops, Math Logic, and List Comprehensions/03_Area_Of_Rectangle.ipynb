# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanBurad/Python-Programming/blob/main/02_Logic_Challenge/Level_1_Loops%2C%20Math%20Logic%2C%20and%20List%20Comprehensions/03_Area_Of_Rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task - 03**
#
# **Write a Function to calculate Area of Rectangle**

# %%
import math as maths
def math_calculation(length,breadth):
  if length&breadth < 0:
    print("Please Enter the Valid Input")
  else:
    area = length * breadth
    print(f"Area = {length} * {breadth} cm")
    print(f"Area of Rectangle is {area} cm.")
X = int(input("Enter the Value of Length : "))
Y = int(input("Enter the Value of Breadth : "))
math_calculation(X,Y)
# Out:
# Enter the Value of Length : 18
# Enter the Value of Breadth : 19
# Area = 18 * 19 cm
# Area of Rectangle is 342 cm.
